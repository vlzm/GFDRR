# %%
# Optional: auto-reload project modules on change (skip if autoreload fails, e.g. on Windows)
try:
    get_ipython().run_line_magic("load_ext", "autoreload")
    get_ipython().run_line_magic("autoreload", "2")
except Exception:
    pass
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Add the project root to the Python path
import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# %%
from gbp.shared.graph_model_mock import GraphMockDataLoader

# %%
loader = GraphMockDataLoader(seed=42)

# %%
graph = loader.load_large()

# %%
graph._edges
# Out:
#   source_id target_id edge_type  distance
# 0   depot_0   depot_8  transfer      6.77
# 1   depot_3   depot_5  transfer      8.86
# 2   depot_5   depot_3  transfer      8.86
# 3   depot_6   depot_0  transfer      5.60
# 4   depot_7   depot_1  transfer     10.95
# 5   depot_7   depot_2  transfer     12.18
# 6   depot_8   depot_5  transfer     11.55
# 7   depot_9   depot_7  transfer      9.93

# %%
graph.node_ids
# Out:
# {'depot_0',
#  'depot_1',
#  'depot_2',
#  'depot_3',
#  'depot_4',
#  'depot_5',
#  'depot_6',
#  'depot_7',
#  'depot_8',
#  'depot_9'}
