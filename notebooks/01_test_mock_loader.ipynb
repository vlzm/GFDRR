# %%
# Optional: auto-reload project modules on change (skip if autoreload fails, e.g. on Windows)
try:
    get_ipython().run_line_magic("load_ext", "autoreload")
    get_ipython().run_line_magic("autoreload", "2")
except Exception:
    pass
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Add the project root to the Python path
import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# %%
from gbp.shared.graph_model_mock import GraphMockDataLoader

# %%
loader = GraphMockDataLoader(seed=42)

# %%
graph = loader.load_large()

# %%
graph._edges
# Out:
#    source_id target_id edge_type  distance
# 0    depot_0   depot_1  transfer      3.74
# 1    depot_0   depot_2  transfer     16.54
# 2    depot_0   depot_3  transfer      4.35
# 3    depot_0   depot_4  transfer     14.36
# 4    depot_0   depot_5  transfer     10.85
# ..       ...       ...       ...       ...
# 85   depot_9   depot_4  transfer     15.72
# 86   depot_9   depot_5  transfer     10.81
# 87   depot_9   depot_6  transfer      4.73
# 88   depot_9   depot_7  transfer      9.93
# 89   depot_9   depot_8  transfer      9.34
#
# [90 rows x 4 columns]
