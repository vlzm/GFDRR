# %%
import pandas as pd

# %%
raw_path = '/Users/vladislav/Documents/vlzm/GFDRR/data/raw/E-Scooter_Trips.csv'
data = pd.read_csv(raw_path)
data.head()
# Out:
#                                 Trip ID              Start Time  \
# 0  82b05060-2520-499d-b82c-b9433e55d313  07/19/2022 02:00:00 PM
# 1  f76efc95-5408-424a-83fd-9f58c31ef05a  07/17/2022 07:00:00 PM
# 2  19540efa-e588-44a4-bcc5-90be074218c4  07/18/2022 06:00:00 PM
# 3  3bd8a49a-25e7-4f3b-ba46-f0c27c248d12  07/17/2022 05:00:00 PM
# 4  540100c8-5989-405d-b85e-107668e31a05  07/19/2022 01:00:00 PM
#
#                  End Time  Trip Distance  Trip Duration Vendor  \
# 0  07/19/2022 02:00:00 PM            593            209   Lime
# 1  07/17/2022 08:00:00 PM           2685            604   Spin
# 2  07/18/2022 06:00:00 PM           1606            532   Lime
# 3  07/17/2022 05:00:00 PM             72            210   Lime
# 4  07/19/2022 02:00:00 PM           1671           2189   Lime
#
#    Start Community Area Number  End Community Area Number  \
# 0                         71.0                       71.0
# 1                          5.0                        6.0
# ...
